# %%
# !pip install --upgrade pip
# !pip install --upgrade datasets[audio] transformers accelerate evaluate jiwer tensorboard gradio
PYTORCH_ENABLE_MPS_FALLBACK=1
PYTORCH_MPS_HIGH_WATERMARK_RATIO=0.0
# Out:
# Requirement already satisfied: pip in /opt/anaconda3/envs/pr3_venv/lib/python3.10/site-packages (24.2)
# zsh:1: no matches found: datasets[audio]

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from datasets import load_dataset, DatasetDict

minds_de_ds = load_dataset('csv', data_files='./MInDS-14/text/de-DE.csv')

train_testvalid = minds_de_ds['train'].train_test_split(test_size=0.2)
# Split the 10% test + valid in half test, half valid
test_valid = train_testvalid['test'].train_test_split(test_size=0.5)
# gather everyone if you want to have a single DatasetDict
ds = DatasetDict({
    'train': train_testvalid['train'],
    'test': test_valid['test'],
    'valid': test_valid['train']})

print(ds)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['filepath', 'text_asr', 'text_translated', 'intent'],
#         num_rows: 488
#     })
#     test: Dataset({
#         features: ['filepath', 'text_asr', 'text_translated', 'intent'],
#         num_rows: 62
#     })
#     valid: Dataset({
#         features: ['filepath', 'text_asr', 'text_translated', 'intent'],
#         num_rows: 61
#     })
# })

# %%
import os
import librosa

def load_audio_data(batch, audio_base_path):
    audio_files = [os.path.join(audio_base_path, filepath) for filepath in batch['filepath']]
    audio_data = [librosa.load(file_path, sr=None) for file_path in audio_files]
    
    # Separate audio data and sample rates
    audio_signals = [data[0] for data in audio_data]
    sample_rates = [data[1] for data in audio_data]
    
    batch['audio'] = [{'path': file_path, 'array': audio, 'sampling_rate': sr} for file_path, audio, sr in zip(audio_files, audio_signals, sample_rates)]
    return batch

# %%
# Apply the function to load audio data and add it to the dataset
audio_base_path = "./MInDS-14/audio"
ds = ds.map(load_audio_data, fn_kwargs={'audio_base_path': audio_base_path}, batched=True)
print(ds)
# Out:
# Map: 100%|██████████| 488/488 [00:00<00:00, 699.56 examples/s]
# Map: 100%|██████████| 62/62 [00:00<00:00, 297.53 examples/s]
# Map: 100%|██████████| 61/61 [00:00<00:00, 640.87 examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['filepath', 'text_asr', 'text_translated', 'intent', 'audio'],
#         num_rows: 488
#     })
#     test: Dataset({
#         features: ['filepath', 'text_asr', 'text_translated', 'intent', 'audio'],
#         num_rows: 62
#     })
#     valid: Dataset({
#         features: ['filepath', 'text_asr', 'text_translated', 'intent', 'audio'],
#         num_rows: 61
#     })
# })

# %%
# Remove the specified columns
ds = ds.remove_columns(["filepath","text_translated", "intent"])

# %%
from datasets import Audio

ds = ds.cast_column("audio", Audio(sampling_rate=16_000))
ds2 = ds
ds['train']['audio']
# Out:
# [{'path': None,
#   'array': array([ 3.02155968e-07,  1.34381844e-05, -4.49617801e-07, ...,
#          -6.04857951e-02, -4.89357859e-02, -2.37017609e-02]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-7.48488947e-06,  1.53290428e-04,  2.53665028e-04, ...,
#          -6.82607875e-04, -5.01901493e-04, -2.07384408e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-8.79698200e-06, -1.31255510e-05,  8.75718251e-06, ...,
#          -7.14519992e-05, -2.77650142e-05,  4.37170165e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.21654365e-04,  9.35820135e-05,  2.20698676e-05, ...,
#           1.61691132e-04,  1.24481285e-05, -5.63955691e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([2.67376570e-04, 2.54679151e-04, 2.18419766e-04, ...,
#          3.94027826e-04, 2.53349106e-04, 4.98622067e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-1.21923404e-05, -2.82285328e-05,  1.19969491e-05, ...,
#          -7.47691374e-04, -2.12493469e-03, -2.00208789e-03]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 4.68769576e-06,  2.67913128e-06, -4.74229273e-06, ...,
#           2.93334277e-04,  2.75355560e-04,  1.11240457e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-7.44283534e-06, -4.20383840e-05,  8.09133780e-06, ...,
#           1.87034765e-03,  1.85494008e-03,  3.45314154e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 8.93417746e-06,  7.04694539e-05, -9.16444696e-06, ...,
#           2.66489154e-03,  2.45742779e-03,  7.34328409e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([2.37614629e-04, 2.74324964e-04, 2.50173849e-04, ...,
#          3.55334487e-05, 2.34781968e-04, 1.84330755e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.64893810e-04, -1.63399265e-04,  2.45279516e-05, ...,
#          -1.70101848e-04, -2.25772645e-04, -1.48478168e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([2.38875888e-04, 2.77112849e-04, 2.49366130e-04, ...,
#          6.52110757e-05, 2.36704800e-04, 1.67678780e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00023684, -0.00038163, -0.00049624, ...,  0.00027711,
#           0.00023888,  0.00012207]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.36084757e-04, -4.00446967e-04, -4.97087021e-04, ...,
#          -1.77096608e-05, -2.40905196e-04, -1.99111935e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 3.11500015e-04,  1.20369106e-04,  1.57799092e-04, ...,
#           2.50982703e-06, -2.46017502e-04, -2.00941446e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.58338405e-04, -1.66938902e-04,  1.69065079e-05, ...,
#          -1.35960381e-05, -2.51749952e-06,  9.47123226e-06]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 3.67873872e-05,  6.98153235e-05, -3.86689717e-05, ...,
#           1.29952561e-02,  1.17323864e-02,  6.29305374e-03]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 0.00024025,  0.00024744,  0.00024764, ..., -0.0215421 ,
#          -0.02116481, -0.01210503]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.40506124e-04,  2.43518807e-04,  2.47199059e-04, ...,
#           1.58964431e-05, -1.94662658e-04, -2.23054143e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00074551, -0.00088775, -0.00071913, ..., -0.00146464,
#          -0.00121823, -0.00056858]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.81089888e-06,  2.54274892e-05, -2.50297308e-06, ...,
#          -4.11127657e-02, -3.16500887e-02, -1.53019801e-02]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 0.00025368,  0.00030559,  0.00023419, ..., -0.00019057,
#          -0.00020694, -0.00016572]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-7.25546852e-06, -2.82948022e-05,  6.05467358e-06, ...,
#           2.86313763e-04,  2.28059638e-04,  1.19653603e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 1.11381523e-05,  4.31714579e-05, -1.22416532e-05, ...,
#          -3.36104655e-04,  1.06029380e-02,  1.11499345e-02]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.0002405 , -0.00027042, -0.00024746, ...,  0.00027567,
#           0.0002849 ,  0.000113  ]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-1.08232052e-05, -2.79770957e-05,  1.12478447e-05, ...,
#          -7.58646056e-05, -4.98690875e-04, -4.15795017e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-4.87244601e-04, -5.90043026e-04, -4.88720601e-04, ...,
#           3.63170868e-04,  2.55708175e-04,  7.08963489e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00025086, -0.00028493, -0.00023674, ..., -0.00030455,
#          -0.00025556, -0.0001043 ]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([2.24913179e-04, 1.44601639e-04, 1.93982851e-05, ...,
#          2.75672326e-04, 2.26701290e-04, 1.21691664e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-6.90439629e-06,  4.15188042e-05,  8.16523971e-06, ...,
#          -2.00375536e-04, -2.51741090e-04, -1.24212078e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 1.15730800e-05, -4.34182584e-06, -1.37025490e-05, ...,
#           2.10180357e-02,  2.74274889e-02,  1.62748955e-02]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 3.39461949e-05,  5.21802103e-05, -3.54505646e-05, ...,
#           2.78304273e-04,  2.44778785e-04,  1.21693971e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00024246, -0.00023124, -0.00024579, ...,  0.00027584,
#           0.00025034,  0.00012478]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-5.20166941e-06,  8.13286752e-05,  2.49810168e-04, ...,
#           7.37108407e-04,  4.82948613e-04,  2.12002371e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([2.31303828e-04, 1.35151640e-04, 1.26576924e-05, ...,
#          2.74865393e-04, 2.22728180e-04, 1.21777499e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.25497555e-04,  1.67687293e-04,  1.99120041e-05, ...,
#          -3.19185434e-04, -2.28989986e-04, -9.74432041e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00047232, -0.00044161, -0.00026058, ...,  0.00027711,
#           0.00023888,  0.00012207]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00022441, -0.00025799, -0.00026427, ...,  0.00019996,
#           0.00025089,  0.00012299]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00048896, -0.00056556, -0.000487  , ...,  0.00027711,
#           0.00023888,  0.00012207]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00066885, -0.00058907, -0.00030877, ...,  0.00024018,
#           0.00023161,  0.00014691]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.00023421, 0.00028185, 0.00025514, ..., 0.0002727 , 0.00024473,
#          0.00012689]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-7.06498977e-04, -8.24379618e-04, -7.58403796e-04, ...,
#           3.85311432e-04,  2.69448035e-04,  5.32306731e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.40708512e-04, -1.40320655e-04, -2.50736775e-06, ...,
#           1.47921480e-02,  1.19741466e-02,  5.73895732e-03]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-8.61969602e-06, -1.32250294e-04, -2.35264626e-04, ...,
#          -8.22303235e-04, -3.08033108e-04,  8.97514474e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00019145, -0.00034111, -0.0003028 , ..., -0.00029531,
#          -0.00026474, -0.00010944]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-1.70006533e-05, -2.45301417e-05,  1.64252124e-05, ...,
#          -1.07159867e-05, -1.26574305e-05,  7.32555600e-06]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 3.03913839e-06,  1.76527246e-05, -3.06880247e-06, ...,
#           2.76654144e-04,  2.37323955e-04,  1.22303711e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.00019941, 0.00018643, 0.00028888, ..., 0.00054727, 0.00066966,
#          0.00045867]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-7.03230151e-04, -5.89014846e-04, -2.73296813e-04, ...,
#           6.01308770e-04,  2.50339363e-04,  2.39208639e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 4.33537934e-07, -6.07516704e-05, -1.08129461e-06, ...,
#          -3.48182279e-04, -2.76176550e-04, -8.53573729e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 4.32927663e-06,  1.30344088e-05, -4.24736936e-06, ...,
#          -4.45483662e-02, -3.89902033e-02, -2.00949274e-02]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 0.00027223,  0.00059001,  0.00070218, ..., -0.00025842,
#           0.00026765,  0.0002832 ]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.42705573e-04, -4.18289157e-04, -4.90545295e-04, ...,
#          -2.08548790e-05, -2.60603556e-04, -2.01946299e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 4.81276395e-04,  5.69774187e-04,  4.94208769e-04, ...,
#          -6.43181091e-04, -2.63644615e-04,  6.50873699e-06]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 0.00049209,  0.00060174,  0.00048424, ..., -0.00046261,
#          -0.00123835, -0.00081049]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.96835788e-06,  1.74306333e-05, -2.65531708e-06, ...,
#           1.02431048e-04,  2.10392260e-04,  1.86474048e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.36310530e-04, -1.87287020e-04, -8.19802517e-06, ...,
#          -2.83165631e-04, -2.55124149e-04, -1.19093187e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.30529986e-04,  1.10802648e-04,  1.24213984e-05, ...,
#          -1.64242840e-04, -2.34569801e-04, -1.52169130e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.00025362, 0.00033512, 0.00023496, ..., 0.00027711, 0.00023888,
#          0.00012207]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 4.92635008e-04,  5.93967736e-04,  4.83044365e-04, ...,
#          -1.79326253e-05, -2.38600289e-04, -1.90608393e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.35437823e-04, -3.81452322e-04, -4.97210014e-04, ...,
#           3.70315393e-04,  2.69218348e-04,  5.18914239e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.00024829, 0.00031802, 0.00023972, ..., 0.00030218, 0.00025014,
#          0.00010472]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-4.25638427e-06,  9.06636487e-05,  2.48808035e-04, ...,
#          -2.77112820e-04, -2.38875946e-04, -1.22070254e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.00021354, 0.00023905, 0.00027691, ..., 0.00029662, 0.00071571,
#          0.00052101]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-1.58830844e-05, -1.30504995e-05,  1.66834707e-05, ...,
#           1.97611007e-05, -1.47700519e-03, -1.19668117e-03]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 0.00028686,  0.00029594,  0.00019893, ..., -0.0002505 ,
#          -0.00024014, -0.00014159]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 1.70723069e-06,  1.37467054e-04,  2.42162903e-04, ...,
#           3.46197976e-06,  5.17756871e-06, -2.49569803e-06]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00024414, -0.00028659, -0.00024401, ..., -0.00027711,
#          -0.00023888, -0.00012207]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-4.73097374e-04, -4.27695399e-04, -2.58994609e-04, ...,
#          -4.30842978e-04, -2.90657219e-04, -2.66366806e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00048404, -0.00059623, -0.0004925 , ...,  0.0002779 ,
#           0.00023887,  0.00012135]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 1.99115108e-04,  2.61834241e-04,  2.91680917e-04, ...,
#           4.53181383e-05, -2.57750158e-04, -2.31940532e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.16300105e-05, -4.85429337e-05,  2.19645153e-05, ...,
#          -1.33255962e-03, -9.81149264e-04, -3.97419557e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.59189983e-06,  9.86303421e-05,  2.47277785e-04, ...,
#           2.77112820e-04,  2.38875917e-04,  1.22070356e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.46144424e-04, -1.52650842e-04,  3.75962736e-06, ...,
#          -3.27144429e-04, -7.05968996e-04, -4.98178764e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-7.32881017e-06,  1.53722824e-04,  2.53836624e-04, ...,
#          -2.77416722e-04, -2.35511048e-04, -1.21304969e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-3.16591468e-07, -2.37314176e-04, -4.88581660e-04, ...,
#           2.55283492e-04,  2.42071954e-04,  1.41698634e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 7.81952258e-06,  1.07126543e-05, -8.10709025e-06, ...,
#           4.25511971e-04,  2.83572590e-04,  2.77171712e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-1.19123724e-05, -3.05608373e-05,  1.22555175e-05, ...,
#          -1.09246094e-03, -1.41802430e-03, -8.80159438e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-7.02084624e-04, -8.57180799e-04, -1.24413986e-03, ...,
#           3.84417741e-04,  2.61696870e-04,  5.86634342e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-9.79581091e-06, -1.15422881e-06,  1.06051739e-05, ...,
#          -1.23904438e-05, -2.12423271e-04, -2.01196613e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.41753994e-04, -2.79607717e-04, -2.46002688e-04, ...,
#          -1.03037892e-05, -2.26248900e-04, -2.06961093e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.00046597, 0.00063693, 0.00075481, ..., 0.00025692, 0.00023797,
#          0.00013417]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.16484827e-04, -1.13003742e-04, -2.65952858e-05, ...,
#          -7.06295203e-03, -5.46536036e-03, -2.54422077e-03]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-5.61667548e-07, -1.01041209e-04, -2.43218907e-04, ...,
#          -2.45290168e-04, -2.40938243e-04, -1.43440586e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-1.43104990e-06,  8.55889812e-06,  1.63458026e-06, ...,
#          -3.29761941e-04, -2.93866731e-04, -8.54444515e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.0004826 , 0.00054985, 0.00049374, ..., 0.00029202, 0.00025662,
#          0.0001115 ]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.24732910e-04, -1.45268568e-04, -1.94772147e-05, ...,
#          -2.29993500e-04, -2.29418074e-04, -1.53295405e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 1.98128895e-04,  1.03477578e-04,  4.82584583e-05, ...,
#          -8.08143159e-06,  2.53243866e-06,  5.83172550e-06]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 1.63789082e-06, -3.38531681e-05, -2.15296313e-06, ...,
#          -2.67960131e-04, -2.26580436e-04, -1.28957734e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.33018742e-04, -2.87390227e-04, -2.54930637e-04, ...,
#           4.83788390e-05,  2.61473324e-04,  1.76478439e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00024408, -0.00028542, -0.00024394, ...,  0.00027664,
#           0.00023294,  0.00012173]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00047829, -0.00056426, -0.00049833, ...,  0.00027711,
#           0.00023888,  0.00012207]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 9.38680023e-06, -1.31342094e-05, -1.08873937e-05, ...,
#           1.41183217e-03,  1.01332704e-03,  3.00106825e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 9.54259485e-06,  1.45166821e-04,  2.34412480e-04, ...,
#           1.79738621e-04,  2.48216056e-05, -6.58765275e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.30706210e-04, -8.09581543e-05, -1.17457239e-05, ...,
#          -1.41145056e-03, -9.88851651e-04, -4.26184386e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.31501152e-04, -2.55752879e-04, -2.56760512e-04, ...,
#           9.25765344e-05,  2.38435925e-04,  1.48094463e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.39163419e-04, -2.57675973e-04, -2.48283090e-04, ...,
#           5.67059215e-05, -1.88885315e-04, -2.38576948e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 0.00018987, -0.00043283, -0.00067823, ...,  0.00027515,
#           0.00024541,  0.00012485]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([2.56207859e-04, 2.79195985e-04, 2.30739810e-04, ...,
#          6.63076789e-05, 2.53869395e-04, 1.68856583e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.07625562e-05,  6.04400993e-05, -2.14225147e-05, ...,
#           2.99452193e-04,  2.41788424e-04,  1.04199309e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00023183, -0.00035039, -0.00050031, ...,  0.00027744,
#           0.00024447,  0.00012246]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 6.65386324e-07, -1.23737569e-04, -2.45168863e-04, ...,
#          -2.07896315e-04, -2.57081236e-04, -7.29117601e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00046975, -0.0005298 , -0.00050713, ...,  0.00027166,
#           0.00024041,  0.00012732]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-1.49776452e-06, -4.53759822e-06,  1.00008583e-06, ...,
#           9.61841829e-03,  6.76481519e-03,  3.16762365e-03]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.31801605e-04, -1.58941024e-04, -1.25546649e-05, ...,
#           2.50447541e-04,  1.92660038e-04,  1.39117270e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-7.26589526e-04, -6.60137448e-04, -2.49905803e-04, ...,
#          -3.32008494e-04, -2.46757292e-04, -9.62598933e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00023891, -0.00029498, -0.00024836, ..., -0.00059045,
#          -0.00047856, -0.00022297]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([7.95262167e-09, 1.29540349e-04, 2.44733994e-04, ...,
#          2.77112762e-04, 2.38875946e-04, 1.22070298e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.58065120e-06,  6.95561175e-06,  2.25596887e-06, ...,
#          -6.41768565e-06, -2.13137391e-04, -2.06275436e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.41133515e-04, -1.63717064e-04, -2.74053309e-06, ...,
#           2.77112849e-04,  2.38875946e-04,  1.22070312e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.21610535e-05, -1.58397248e-04, -2.21115071e-04, ...,
#          -1.66232076e-06, -5.93805999e-06,  7.89837031e-07]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-6.95361086e-06, -2.48495024e-04, -4.81613679e-04, ...,
#           2.73919257e-04,  2.37727087e-04,  1.24737577e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-7.71571649e-07, -1.23969367e-04, -2.43357645e-04, ...,
#           2.98475788e-04,  2.41433794e-04,  1.06603831e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-9.43912528e-06, -1.92549724e-05,  9.51142283e-06, ...,
#           1.61777221e-04,  1.05737381e-05, -5.65361843e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-4.80467570e-04, -5.17018547e-04, -4.95400513e-04, ...,
#          -3.95776733e-04, -2.55919062e-04, -5.17176632e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-1.44236528e-05,  5.82624853e-06,  1.66945392e-05, ...,
#           2.01110175e-04,  2.48642609e-04,  1.21486133e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-7.77494279e-06, -7.12550245e-05,  7.46340811e-06, ...,
#          -2.86169699e-04, -2.45042029e-04, -1.17172043e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([1.86001576e-04, 4.50319130e-05, 5.94403391e-05, ...,
#          1.56456925e-04, 2.41469417e-04, 1.55041780e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.37782995e-04, -1.61546050e-04, -6.12148142e-06, ...,
#           2.77112820e-04,  2.38875946e-04,  1.22070254e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.35988395e-04,  7.45856232e-05, -2.35856583e-04, ...,
#           2.92544253e-04,  2.42808834e-04,  1.12917740e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-1.34975999e-05, -1.48809602e-04, -2.30376972e-04, ...,
#           4.00929828e-04,  4.69082239e-04,  2.93740391e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-4.72889951e-06,  3.94876406e-06,  5.89147385e-06, ...,
#           1.62486191e-04,  9.47476019e-06, -5.68045361e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 3.64484731e-06,  2.05552060e-05, -4.09452332e-06, ...,
#           1.03963466e-04, -1.85191107e-04, -2.70722026e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 7.67596066e-06, -2.01370567e-05, -8.90716910e-06, ...,
#          -9.57716722e-04, -7.20403739e-04, -3.27472459e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.32282560e-04,  1.21931080e-05, -2.32248567e-04, ...,
#           2.83857342e-03,  2.37659412e-03,  1.18260679e-03]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-7.27289182e-04, -8.56042840e-04, -7.36449379e-04, ...,
#           3.09479001e-05,  2.32001767e-04,  1.90486462e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00446809, -0.00587604, -0.00554163, ...,  0.00028458,
#           0.0002529 ,  0.00011795]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00024443, -0.00031329, -0.00024379, ...,  0.00026704,
#           0.00023425,  0.00012985]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.00023888, 0.00027711, 0.00024937, ..., 0.00027711, 0.00023888,
#          0.00012207]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-1.64931898e-05,  9.59121826e-06,  1.86107682e-05, ...,
#           3.10140953e-04,  2.47905351e-04,  1.04095867e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00023888, -0.00027711, -0.00024937, ..., -0.00027711,
#          -0.00023888, -0.00012207]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.48156110e-04,  3.34308424e-04,  2.39529400e-04, ...,
#          -3.12795048e-04, -2.43914867e-04, -9.54234856e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.40122608e-06,  9.87157400e-05,  2.46638112e-04, ...,
#           2.83743546e-04, -2.08251193e-04, -2.95527949e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.40901019e-04, -3.05129099e-04, -2.47481978e-04, ...,
#           3.06598435e-04,  2.42894530e-04,  9.57960001e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00047694, -0.0006649 , -0.00074367, ..., -0.00029446,
#          -0.00023994, -0.00010649]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.38868219e-04, -1.83926095e-04, -5.81899076e-06, ...,
#           5.71825440e-05,  2.26311095e-04,  1.73733002e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([2.41454749e-04, 2.72346137e-04, 2.45924311e-04, ...,
#          8.86270791e-05, 2.71967991e-04, 1.51452477e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-1.81373944e-05, -1.89575192e-04, -2.26353135e-04, ...,
#           2.70754535e-04,  2.29252415e-04,  1.25842096e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-8.62847810e-06, -1.27969979e-05,  8.81699816e-06, ...,
#          -7.79496168e-06, -3.60227614e-06,  6.92790127e-06]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00073398, -0.00086624, -0.00073036, ...,  0.00029494,
#           0.0002697 ,  0.00011133]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.44231545e-04,  2.13682884e-04,  8.34472303e-07, ...,
#          -2.41017784e-04, -2.20990158e-04, -1.46667619e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([2.34158957e-04, 1.52787761e-04, 9.89540422e-06, ...,
#          3.64915817e-04, 4.31186892e-03, 3.35076358e-03]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 8.49971548e-06,  6.38980418e-06, -8.70961230e-06, ...,
#           1.04042999e-02,  7.33678276e-03,  3.21018370e-03]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.50928861e-06,  1.01388134e-04,  2.46966723e-04, ...,
#           2.77112849e-04,  2.38875946e-04,  1.22070312e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00049023, -0.00055964, -0.00048496, ...,  0.00027711,
#           0.00023888,  0.00012207]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([2.49559351e-04, 2.71399418e-04, 2.36893029e-04, ...,
#          8.07936594e-05, 2.74409540e-04, 1.57442584e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.04405966e-04,  1.21647099e-04,  4.05727187e-05, ...,
#           4.53447210e-05, -4.18409560e-04, -5.06961136e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00020747,  0.00027291,  0.00069455, ...,  0.00019335,
#           0.0002273 ,  0.00018354]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.23965268e-04,  1.42536926e-04,  2.12970590e-05, ...,
#           4.93758172e-03,  1.61092589e-03, -4.00033779e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-1.28161628e-06, -2.72814359e-05,  1.25991210e-06, ...,
#           4.72247048e-04,  3.01288470e-04,  3.78543336e-06]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-1.55071757e-06, -9.43221676e-06,  1.80504139e-06, ...,
#           2.77112820e-04,  2.38875931e-04,  1.22070312e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.37032305e-04,  1.71770211e-04,  6.91831519e-06, ...,
#           4.24095924e-06,  4.57433634e-06, -3.05271533e-06]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00023277, -0.00038511, -0.00049994, ..., -0.00028629,
#          -0.00023043, -0.00011359]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.37886430e-04, -1.58710624e-04, -6.21075742e-06, ...,
#           1.12031048e-04, -1.89774932e-04, -2.79656495e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00023888, -0.00027711, -0.00024937, ..., -0.00027712,
#          -0.00023887, -0.00012207]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.00023888, 0.00027711, 0.00024937, ..., 0.00027711, 0.00023888,
#          0.00012207]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 0.00023376,  0.00023512,  0.00025418, ..., -0.00015937,
#          -0.00027455, -0.00011196]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([2.38155568e-04, 1.59677729e-04, 5.52150595e-06, ...,
#          3.20909453e-06, 2.43322080e-04, 1.98859430e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.37475178e-04, -1.63321209e-04, -6.48397690e-06, ...,
#           5.68904448e-04,  2.50744575e-04,  3.45398003e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-5.03249476e-06,  3.00635293e-07,  5.51090397e-06, ...,
#          -4.06723811e-05, -1.86209636e-05,  2.89144518e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([2.59365363e-04, 3.36550962e-04, 2.27126700e-04, ...,
#          3.65160056e-04, 2.57498003e-04, 6.99933662e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 1.59840565e-05,  1.60864540e-04,  2.27920420e-04, ...,
#          -1.24759157e-03, -1.17823947e-03, -6.52616960e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.51427991e-04, -1.16992378e-04,  9.02952161e-06, ...,
#           3.86819920e-05,  1.50232618e-05, -2.53398248e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.47433258e-04,  2.85810907e-04,  2.40483714e-04, ...,
#          -1.39403710e-07,  2.39262386e-04,  1.97599409e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.64734728e-04, -1.05929925e-04,  2.65374372e-04, ...,
#          -3.09263880e-04, -2.53573002e-04, -9.95724622e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 0.00026242,  0.0002764 ,  0.00022314, ..., -0.00087737,
#          -0.00074259, -0.00034269]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-7.06410501e-04, -9.48993198e-04, -1.00315432e-03, ...,
#          -3.23915709e-04, -2.44715920e-04, -8.59610300e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.00876956, 0.01024037, 0.00856411, ..., 0.00541106, 0.00433525,
#          0.00227545]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-4.72255488e-06, -1.32974150e-04, -2.39127141e-04, ...,
#           3.76536231e-03,  3.31426179e-03,  1.77221757e-03]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 7.63429489e-06,  1.50696811e-04,  2.36362830e-04, ...,
#           1.39196025e-04, -7.59320574e-06, -3.98216434e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.10825179e-04,  2.71724828e-04,  2.80445645e-04, ...,
#          -1.07453307e-05,  2.05224947e-04,  2.04177399e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-1.18971948e-05, -1.28519969e-05,  1.32997084e-05, ...,
#           8.47476185e-05, -1.24726957e-05, -6.84824772e-06]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.57137348e-04, -3.80863290e-04, -2.32440405e-04, ...,
#           5.26720367e-04,  2.71666649e-04,  6.07832917e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 0.00024105,  0.00027831,  0.0002472 , ...,  0.00027814,
#          -0.00021349, -0.00029146]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00023374, -0.00028025, -0.00025479, ...,  0.000126  ,
#           0.00026784,  0.00013969]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.16387853e-05, -8.56370752e-05,  2.13308667e-05, ...,
#          -2.84794114e-05, -1.11754343e-05,  1.22087949e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.52501311e-04, -2.19236594e-04,  9.36948345e-06, ...,
#          -8.63796100e-04, -7.28694082e-04, -3.44347558e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00022758, -0.00024728, -0.00026064, ..., -0.00046012,
#          -0.00070152, -0.00042406]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-8.00627458e-06, -8.67488416e-06,  8.00973794e-06, ...,
#          -5.34427818e-05, -7.17047078e-06,  3.11218319e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([2.49201490e-04, 2.64678907e-04, 2.38398687e-04, ...,
#          4.42235498e-04, 2.98235507e-04, 1.79523795e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00023095, -0.00027149, -0.0002578 , ...,  0.00027846,
#           0.00025385,  0.0001229 ]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 1.89124148e-06, -5.29551153e-06, -2.46189848e-06, ...,
#          -4.70127634e-06, -2.27120239e-04, -1.96379668e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 1.86832622e-05, -8.67978670e-05, -2.63565453e-04, ...,
#          -5.72551449e-04, -4.60454903e-04, -2.79464934e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-1.89151979e-06, -4.09837230e-06,  1.45853846e-06, ...,
#           1.12224356e-04, -4.77180174e-06, -2.14997199e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.53754406e-04,  3.77505057e-04,  2.34440129e-04, ...,
#          -4.04212042e-05, -2.27403332e-04, -1.80982170e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-1.81591808e-04,  1.84214441e-05,  1.77975206e-04, ...,
#           6.44355780e-04,  6.80852332e-04,  4.13150876e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00023412, -0.00032505, -0.00025462, ..., -0.00027076,
#          -0.00024398, -0.00012866]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.35640997e-04, -1.59787058e-04, -8.09566700e-06, ...,
#          -2.33943894e-04, -2.09508667e-04, -1.49283238e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00022823, -0.00029999, -0.00026071, ...,  0.00611168,
#           0.0058139 ,  0.00316278]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.16736225e-07, -4.82229552e-06, -6.90240995e-07, ...,
#           5.15653410e-05,  7.83260111e-06, -3.05775720e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.41934686e-04,  2.60828354e-04,  2.46449345e-04, ...,
#          -1.73929002e-05, -2.41325586e-04, -1.88949911e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.18333924e-04,  1.37645678e-04,  2.66630159e-05, ...,
#          -8.86926986e-03, -6.87849708e-03, -3.19371233e-03]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00023957, -0.00026238, -0.00024777, ...,  0.00021431,
#           0.00021384,  0.00017029]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 1.58180264e-05,  3.40472907e-05, -1.51916392e-05, ...,
#          -4.40175245e-06, -7.60684998e-07,  4.19881417e-06]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00072741, -0.00083923, -0.00073664, ...,  0.00027452,
#           0.00021748,  0.00012147]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00024358, -0.00028069, -0.00024447, ...,  0.00027711,
#           0.00023888,  0.00012207]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-1.35358423e-05, -9.34058335e-06,  1.44112419e-05, ...,
#           8.51083314e-06, -1.12999442e-06, -5.99091982e-06]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.0002349 , 0.00022568, 0.00025224, ..., 0.00620051, 0.00535667,
#          0.00276683]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-3.97124040e-06,  3.96877658e-05,  4.57033821e-06, ...,
#          -1.14440933e-04, -2.47161486e-04, -1.80788425e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-4.65633522e-04, -4.24797006e-04, -2.66378862e-04, ...,
#           3.83749750e-04,  2.48336117e-04,  5.68841060e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 1.42767713e-05,  2.13184758e-04,  2.31261278e-04, ...,
#          -8.66879534e-04, -7.24896439e-04, -3.48033151e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 6.08002301e-06, -2.09249265e-06, -5.96736209e-06, ...,
#          -5.95252961e-04, -7.17519899e-04, -4.26496495e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-4.84523742e-04, -5.45997813e-04, -4.91595420e-04, ...,
#           3.22188134e-05,  2.28179852e-04,  1.88140184e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.00046806, 0.00051459, 0.00050854, ..., 0.00027711, 0.00023888,
#          0.00012207]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 0.00023443,  0.00026012,  0.00025404, ..., -0.00023694,
#          -0.00021261, -0.00015307]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.52161059e-04,  1.98043417e-04, -7.87572935e-06, ...,
#          -2.34790775e-03, -2.36785086e-03, -1.39641715e-03]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 7.17992953e-06,  2.14482570e-05, -6.94891787e-06, ...,
#          -9.91178770e-03, -8.28898884e-03, -4.09770757e-03]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 9.16048884e-06,  5.05894423e-06, -9.78074968e-06, ...,
#           1.18980977e-04,  2.27669036e-04,  1.75501482e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.00024051, 0.00027542, 0.00024757, ..., 0.00027868, 0.00023468,
#          0.00012008]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-6.77492062e-06,  1.27694133e-04,  2.50673504e-04, ...,
#          -3.45646928e-04, -2.69586686e-04, -7.85845841e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.00072683, 0.00055617, 0.0002462 , ..., 0.0001913 , 0.00020116,
#          0.00018148]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.67551513e-06,  1.50577398e-06,  2.48686410e-06, ...,
#          -1.67185150e-04, -2.37564411e-04, -1.47130457e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([2.23235213e-04, 1.40672651e-04, 2.10401777e-05, ...,
#          2.78144464e-04, 2.39614310e-04, 1.21188874e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 5.05463686e-06,  3.58342368e-06, -4.87962097e-06, ...,
#          -2.74414429e-04, -2.24381336e-04, -1.22480880e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-4.67008853e-04, -4.27639985e-04, -2.65429553e-04, ...,
#          -2.17039742e-05, -2.13541614e-04, -1.96030262e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.47748598e-04, -3.79923586e-04, -4.83613519e-04, ...,
#           3.19774845e-05,  2.60295754e-04,  1.76326706e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 6.24728273e-06,  1.13267306e-05, -6.78042124e-06, ...,
#          -1.15218034e-04, -4.66295569e-06,  2.92757031e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 1.45179656e-05, -1.19591568e-05, -1.76355607e-05, ...,
#           9.23489861e-05, -1.97224595e-04, -2.60760542e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00023959, -0.00028927, -0.00024785, ..., -0.00027711,
#          -0.00023888, -0.00012207]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.40215173e-04, -1.53766188e-04, -2.73864862e-06, ...,
#           6.95489143e-06, -7.17416697e-06, -8.00426642e-06]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 6.62279126e-06,  2.91832985e-05, -6.30232535e-06, ...,
#           1.32037225e-04,  1.99100527e-04,  1.80642353e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.0002537 , 0.0002909 , 0.00023357, ..., 0.00023988, 0.00022081,
#          0.00014715]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-4.45490878e-06,  3.73591320e-06,  4.86629142e-06, ...,
#          -2.60531728e-04, -2.17861190e-04, -1.32748770e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.38411114e-04,  1.60199765e-04,  5.74355363e-06, ...,
#          -5.20748571e-02, -4.66582254e-02, -2.44243406e-02]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 0.00024752,  0.00028534,  0.00023964, ..., -0.00010411,
#          -0.00025209, -0.00013836]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-8.16467218e-06,  6.59542275e-06,  9.70458495e-06, ...,
#           1.00904494e-04,  2.18701840e-04,  1.85766898e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([2.31946353e-04, 1.19290125e-04, 1.10730543e-05, ...,
#          1.35891177e-02, 1.29381176e-02, 6.89306390e-03]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00025886, -0.00030586, -0.00022735, ...,  0.00155635,
#           0.00144483,  0.00075405]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.00024441, 0.0002961 , 0.00024365, ..., 0.00028736, 0.00021807,
#          0.00010974]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00024906, -0.00033755, -0.00023909, ..., -0.00026373,
#          -0.00021412, -0.00014847]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([2.29653844e-04, 1.46352162e-04, 1.38322102e-05, ...,
#          2.73135549e-04, 2.41667396e-04, 1.23291320e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-1.27720705e-06,  7.75326043e-06,  1.44346268e-06, ...,
#          -3.57437122e-04, -2.15863576e-04, -7.44386489e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 0.00023393,  0.00031422,  0.00025564, ..., -0.00028683,
#          -0.00022819, -0.00011196]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.39092333e-06, -3.66588938e-06,  2.46772834e-06, ...,
#           2.70899938e-04,  2.42733324e-04,  1.27913008e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.32210470e-04,  4.13717353e-05, -2.32334685e-04, ...,
#           3.51908733e-04,  4.74503729e-04,  2.87068688e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([2.47256656e-04, 3.42200714e-04, 2.40712950e-04, ...,
#          3.68316396e-04, 2.52244907e-04, 7.21622346e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.45391187e-04, -1.96292283e-04,  8.75981641e-07, ...,
#           1.91124782e-05,  7.04622471e-06, -7.05129059e-06]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 0.00024599,  0.00031833,  0.00024275, ..., -0.00013745,
#          -0.00022785, -0.00016105]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-4.64032928e-06, -1.08115077e-04, -2.39321642e-04, ...,
#           2.77112878e-04,  2.38875946e-04,  1.22070276e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-6.48295008e-06, -1.70713465e-04, -2.37348198e-04, ...,
#           1.00580386e-04,  2.37078144e-04,  1.85664656e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.00048914, 0.00059093, 0.00048683, ..., 0.00027746, 0.00024653,
#          0.00012255]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 0.00048507,  0.00056445,  0.00049106, ..., -0.00025621,
#          -0.00022615, -0.00013708]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([2.30000122e-04, 1.49640153e-04, 1.36109957e-05, ...,
#          1.82415184e-04, 2.51414633e-04, 1.38112053e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 1.49104744e-05,  3.65413725e-05, -1.62553042e-05, ...,
#          -3.03435768e-03, -2.63604242e-03, -1.31607300e-03]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.20033951e-04, -2.70162272e-05,  2.20555798e-04, ...,
#           2.43170914e-04,  4.19961543e-05, -1.16602736e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-4.49418440e-06, -1.21970719e-04, -2.39351371e-04, ...,
#          -2.81910587e-04, -2.26654796e-04, -1.16067145e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.0007301 , 0.00087038, 0.00073415, ..., 0.00026119, 0.00022076,
#          0.00013278]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.00023888, 0.00027711, 0.00024937, ..., 0.00027711, 0.00023888,
#          0.00012207]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([2.42084730e-04, 1.71036663e-04, 2.03777745e-06, ...,
#          2.38786946e-04, 2.06542958e-04, 1.50073465e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.00046701, 0.00040601, 0.0002654 , ..., 0.00058755, 0.00071804,
#          0.00043348]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.48860975e-04,  3.56106088e-04,  2.40117297e-04, ...,
#           3.87745531e-05, -2.16512402e-04, -2.27973651e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-1.03718194e-05,  5.34535502e-06,  1.12140988e-05, ...,
#           2.77112849e-04,  2.38875975e-04,  1.22070327e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 1.05909203e-05,  1.05641375e-05, -1.09263492e-05, ...,
#          -2.92419863e-05,  2.47272139e-04,  2.24678166e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 1.82003478e-05,  2.21185750e-04,  2.26416130e-04, ...,
#          -1.96853391e-04, -2.13754247e-05,  8.05826276e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.15808861e-04, -2.28807330e-05, -2.16366723e-04, ...,
#           3.78616620e-03,  3.57786543e-03,  1.93323242e-03]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.22742063e-04, -4.78021393e-05, -2.24361371e-04, ...,
#           2.50571495e-04,  1.97587360e-04,  1.38113275e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 4.66119265e-04,  3.39093269e-04,  2.26391276e-05, ...,
#           8.35605781e-04,  2.80411798e-04, -2.96949875e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 1.96653797e-04, -4.48781066e-05, -1.93556087e-04, ...,
#          -1.02953185e-04, -2.64190545e-04, -1.41256882e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.30937614e-04,  1.31317182e-04,  1.28232059e-05, ...,
#          -4.18186886e-03, -3.93107114e-03, -2.14655558e-03]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-4.40792064e-07, -7.59399700e-06,  2.33005267e-07, ...,
#           5.92533906e-04,  7.40635209e-04,  4.26442595e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.31656901e-04,  1.76550384e-05, -2.32453720e-04, ...,
#          -5.91501521e-05, -2.48300959e-04, -1.68705345e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.47230520e-04,  2.83293193e-04,  2.40535475e-04, ...,
#          -3.03413981e-05, -2.18774192e-04, -1.88126724e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 4.89007914e-04,  5.85578848e-04,  4.87006851e-04, ...,
#          -3.30525363e-04, -2.57404317e-04, -9.73508286e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.00023888, 0.00027711, 0.00024937, ..., 0.00027711, 0.00023888,
#          0.00012207]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([7.37720984e-06, 1.22280719e-04, 2.36997934e-04, ...,
#          2.57166568e-04, 2.17923094e-04, 1.36754534e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-7.05767889e-09, -5.64438596e-05, -3.47477908e-07, ...,
#           2.77112878e-04,  2.38875931e-04,  1.22070327e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.75361468e-04,  1.58650480e-04, -3.44399741e-05, ...,
#          -1.37247480e-05, -2.29980884e-04, -1.89202095e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.47878837e-04,  4.63142642e-05, -2.48629309e-04, ...,
#           2.66089628e-04,  2.23353767e-04,  1.29683263e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 1.30864209e-05,  2.08987040e-05, -1.34548172e-05, ...,
#          -4.58545896e-04, -4.99679649e-04, -2.45371426e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 3.69730697e-06, -1.55115558e-05, -4.01661964e-06, ...,
#          -1.04092687e-05,  2.43607006e-04,  2.09102756e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00048136, -0.00061805, -0.0004954 , ...,  0.00024254,
#           0.00022423,  0.00014377]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.60861998e-06,  5.52707425e-05, -1.42146928e-06, ...,
#           4.38717543e-04,  2.47495132e-04,  7.10700406e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-1.07551750e-06, -8.02995055e-06,  1.01655314e-06, ...,
#           2.63685768e-04,  1.92853186e-04,  1.28626401e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([2.41151414e-04, 1.84729317e-04, 3.24480789e-06, ...,
#          2.77112820e-04, 2.38875902e-04, 1.22070312e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 0.00023755,  0.0002521 ,  0.00025065, ..., -0.00023978,
#          -0.00023045, -0.00014726]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 1.88127160e-07, -1.99723872e-05, -6.38625352e-07, ...,
#           2.77112820e-04,  2.38875946e-04,  1.22070327e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.00024512, 0.00028294, 0.00024241, ..., 0.00028092, 0.0002527 ,
#          0.00012061]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-8.66603659e-06, -2.47804681e-04, -4.79939452e-04, ...,
#          -9.71981382e-04,  1.93487038e-04,  4.61657881e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.00025965, 0.00029964, 0.00022703, ..., 0.00027563, 0.00022646,
#          0.0001217 ]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.0002333 , 0.00025454, 0.00025538, ..., 0.00030123, 0.00025811,
#          0.000106  ]),
#   'sampling_rate': 16000},
# ...
#  {'path': None,
#   'array': array([1.83583434e-05, 1.56640803e-04, 2.24884716e-04, ...,
#          2.86668073e-04, 2.57136300e-04, 1.16809271e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.49305624e-04, -3.44489177e-04, -2.39048706e-04, ...,
#           3.04775487e-04,  2.52145401e-04,  9.86719824e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([2.31013575e-04, 1.32695292e-04, 1.27160165e-05, ...,
#          2.45404692e-04, 2.74655904e-04, 9.97848547e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00024146, -0.00030068, -0.00024685, ...,  0.00028989,
#           0.00026283,  0.00011379]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.14096144e-06,  6.81874371e-06, -1.54557347e-06, ...,
#          -1.65252586e-05,  8.13290171e-07,  1.45410195e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-8.02290742e-07, -2.14537577e-05,  1.98146154e-07, ...,
#           2.02000607e-04,  2.01400020e-04,  1.72546090e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 1.95030589e-06, -4.18003037e-06, -2.01862713e-06, ...,
#           4.38815223e-05, -1.97447313e-04, -2.28652905e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.00022743, 0.00027609, 0.00026191, ..., 0.00027711, 0.00023888,
#          0.00012207]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-5.97550388e-06, -1.31121575e-04, -2.38553373e-04, ...,
#          -3.49806272e-04, -2.50009703e-04, -8.31499055e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([2.78083084e-04, 2.89217423e-04, 2.06906043e-04, ...,
#          4.29920561e-04, 2.93756253e-04, 2.78781608e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.25679672e-04, -1.44426886e-04, -1.88027552e-05, ...,
#          -3.76942247e-04, -2.60576024e-04, -6.84818078e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.44086114e-04,  3.15442623e-04,  2.44605588e-04, ...,
#          -6.70063309e-06,  2.47194897e-04,  2.07395147e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.47438176e-04,  2.81098997e-04,  2.40419569e-04, ...,
#          -2.77781583e-05,  2.27714729e-04,  2.15476291e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.32795399e-04, -1.32591289e-04, -1.11619047e-05, ...,
#          -1.76006870e-04, -2.32538398e-04, -1.39713811e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-7.24119673e-06,  6.94472692e-06,  8.81995220e-06, ...,
#           3.86600569e-02,  5.60119301e-02,  3.84841599e-02]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00046794, -0.00053228, -0.00050869, ...,  0.00019101,
#           0.00021672,  0.00018376]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00048213, -0.00052051, -0.00049327, ..., -0.00030095,
#          -0.00023719, -0.00011768]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([2.61076639e-04, 3.30401817e-04, 2.25900192e-04, ...,
#          3.94406205e-04, 2.67970492e-04, 5.05612697e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.05166521e-04, -5.21412803e-05, -2.04235141e-04, ...,
#          -2.72842182e-04, -2.55953899e-04, -1.19468328e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([2.29875572e-04, 1.32044952e-04, 1.34378170e-05, ...,
#          1.20715777e-04, 2.26633245e-04, 1.78650269e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.37658154e-04,  1.70632498e-04,  6.50971197e-06, ...,
#           2.35966407e-04,  2.67387368e-05, -9.60314064e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 9.73931310e-06,  1.49152387e-04,  2.34553823e-04, ...,
#          -4.86973731e-04, -4.67475445e-04, -2.88431183e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([4.66541591e-04, 6.39697362e-04, 7.54580658e-04, ...,
#          9.46379168e-06, 2.14383006e-04, 2.04160984e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.0004608 , -0.0004095 , -0.00027173, ...,  0.00027711,
#           0.00023888,  0.00012207]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.00021549, 0.00023314, 0.00027252, ..., 0.00434024, 0.00272991,
#          0.00089845]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.41510570e-05, -1.27053005e-04, -2.18276517e-04, ...,
#           3.21349129e-03,  2.84879981e-03,  1.56667351e-03]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-1.61458411e-05, -1.57768663e-04, -2.26891556e-04, ...,
#          -4.33401146e-04, -4.53789835e-04, -2.82382854e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00024046, -0.00030642, -0.00024749, ..., -0.00030016,
#          -0.00026854, -0.00010836]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 3.99666169e-06,  1.22415258e-06, -4.26454062e-06, ...,
#           1.15770599e-05, -1.60277486e-05, -1.81285668e-06]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00031422, -0.00039298, -0.00016878, ..., -0.01000611,
#          -0.00375997, -0.00058368]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.86569411e-06,  3.90849164e-06, -2.82799010e-06, ...,
#           1.54753623e-04,  9.19917147e-06, -4.75555207e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.51823047e-04, -3.16359801e-04, -2.35947213e-04, ...,
#          -3.44697692e-05,  2.03016913e-04,  2.33367391e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.50103651e-04,  1.60804600e-04, -7.09356391e-06, ...,
#           6.08760965e-05,  2.33595259e-04,  1.73856184e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00048944, -0.00059561, -0.00048692, ..., -0.00026907,
#          -0.00022614, -0.00012767]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00070738, -0.00059801, -0.00026908, ...,  0.00027711,
#           0.00023888,  0.00012207]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.41645466e-06,  3.57037934e-05, -2.39041401e-06, ...,
#           5.98828541e-04,  6.98948163e-04,  4.20481490e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 4.93320986e-04,  5.80925494e-04,  4.82677366e-04, ...,
#          -1.23251157e-05,  2.50023440e-04,  2.10239639e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.28261342e-04, -1.47905434e-04, -1.55484304e-05, ...,
#           4.63443110e-03,  2.08796654e-03,  4.46303748e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.01039588, -0.01343666, -0.00937634, ...,  0.0002626 ,
#           0.00019438,  0.00012729]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.36228749e-04, -1.69278181e-04, -7.88932084e-06, ...,
#          -2.77112820e-04, -2.38875960e-04, -1.22070305e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.86735303e-06, -1.19747841e-04, -2.41794813e-04, ...,
#           2.77112849e-04,  2.38875946e-04,  1.22070312e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.94222846e-05, -7.32220360e-05,  3.05574504e-05, ...,
#          -4.13748639e-04, -2.33517931e-04, -8.43943271e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-1.22624479e-05, -5.11165417e-05,  1.25029619e-05, ...,
#           3.91176296e-03,  4.44210507e-03,  2.48193229e-03]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 0.00024221,  0.00026795,  0.0002454 , ..., -0.00026828,
#          -0.00021913, -0.00012739]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 4.97848843e-04,  6.09400799e-04,  4.78170521e-04, ...,
#           8.43451126e-05, -2.21165712e-04, -2.62923219e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.18671034e-04, -1.47923434e-04, -2.65556300e-05, ...,
#           1.32658915e-03,  1.17796799e-03,  6.13724114e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 0.00070614,  0.00068521,  0.00051483, ..., -0.00027323,
#          -0.00028608, -0.00013193]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.59857974e-04,  1.66701575e-05, -2.64597707e-04, ...,
#           2.90873781e-04,  2.43050832e-04,  1.10012428e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.10438360e-04,  6.92397080e-05,  2.11210703e-04, ...,
#           1.81801341e-04,  2.06973287e-04,  1.73599023e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.27235596e-05, -9.29860107e-06,  2.44550029e-05, ...,
#          -3.94385960e-03, -3.61057348e-03, -2.00650818e-03]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 0.00855841, -0.0002448 , -0.01374348, ...,  0.00027711,
#           0.00023888,  0.00012207]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([5.97814505e-07, 1.41640310e-04, 2.44319410e-04, ...,
#          2.44400580e-04, 1.94490625e-04, 1.43799392e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.00024485, 0.0002782 , 0.00024312, ..., 0.00027711, 0.00023888,
#          0.00012207]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00025656, -0.00044566, -0.00047561, ..., -0.00012314,
#          -0.0002265 , -0.00017207]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00048561, -0.00058314, -0.00049019, ...,  0.00093855,
#           0.00073892,  0.00031248]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00023822, -0.00025191, -0.00024987, ...,  0.00027711,
#           0.00023888,  0.00012207]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([2.37146611e-04, 2.62766669e-04, 2.51494232e-04, ...,
#          4.13681264e-04, 3.01477965e-04, 4.08318665e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-1.24111693e-05,  5.00533770e-06,  1.42957879e-05, ...,
#           1.97466841e-04,  2.77054241e-05, -7.45306170e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.24281772e-04, -2.99838139e-05,  2.23688126e-04, ...,
#          -3.97934928e-05, -2.75455881e-04, -1.85390789e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00023213, -0.00039103, -0.00050116, ..., -0.00027845,
#          -0.00023977, -0.00012097]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.00023888, 0.00027711, 0.00024937, ..., 0.00027711, 0.00023888,
#          0.00012207]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([2.39167537e-04, 2.83552101e-04, 2.48878263e-04, ...,
#          3.14821664e-04, 2.55372724e-04, 9.13057156e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00048605, -0.00056607, -0.00049007, ..., -0.00028304,
#          -0.00014026, -0.0001201 ]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.00023888, 0.00027711, 0.00024937, ..., 0.00027711, 0.00023888,
#          0.00012207]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-5.41095505e-06, -9.77668242e-06,  5.16830914e-06, ...,
#           2.83015426e-04,  2.42021575e-04,  1.17018688e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00024258, -0.00025473, -0.00024496, ...,  0.00028063,
#           0.00024138,  0.00011915]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-4.19092066e-06,  1.24783386e-04,  2.48231110e-04, ...,
#           5.53039322e-03,  5.99032827e-03,  3.13586649e-03]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-4.72593209e-04, -3.37070902e-04, -1.59830088e-05, ...,
#          -6.22267835e-05,  2.16924003e-04,  2.42190596e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.00023888, 0.00027711, 0.00024937, ..., 0.0002818 , 0.00023413,
#          0.00011711]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.26729535e-05,  9.06925125e-05, -2.22132039e-05, ...,
#           1.67278689e-04,  8.20050627e-06, -6.07677830e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.36767577e-04, -1.58804309e-04, -7.72761996e-06, ...,
#           2.87169416e-04,  2.56751315e-04,  1.16017494e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.44119001e-04, -2.78327003e-04, -2.43837610e-04, ...,
#           3.31862422e-04,  2.40824520e-04,  9.54466377e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.00028326, 0.0003089 , 0.00020105, ..., 0.00027253, 0.00022109,
#          0.00012398]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.08935235e-05, -1.66973099e-04, -2.23228941e-04, ...,
#           2.20454391e-03,  2.59656413e-03,  1.54391804e-03]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.50502606e-04, -8.20823043e-05,  2.49404431e-04, ...,
#           2.83138710e-04,  2.62923539e-04,  1.18743723e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.00023698, 0.00028748, 0.00025135, ..., 0.00027711, 0.00023888,
#          0.00012207]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.00628652e-04, -9.39679448e-05, -2.00900773e-04, ...,
#           3.19761923e-04,  2.79837055e-04,  9.47379594e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-7.07663276e-06,  4.51630331e-06,  7.56781083e-06, ...,
#           3.42661864e-04,  2.37559914e-04,  8.49413773e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.00023957, 0.00038824, 0.00049318, ..., 0.00027772, 0.00023762,
#          0.00012134]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 1.96616456e-05,  1.85586920e-04,  2.24516814e-04, ...,
#          -9.23670523e-05, -2.40942143e-04, -1.89038707e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00023773, -0.00024377, -0.00025018, ..., -0.00027711,
#          -0.00023888, -0.00012207]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00024283, -0.00027993, -0.00024531, ..., -0.00027098,
#          -0.00024893, -0.00012364]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.00023918, 0.00027746, 0.00024908, ..., 0.00027613, 0.00022725,
#          0.00012148]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-2.42167152e-06, -1.67127000e-05,  2.58197542e-06, ...,
#          -7.54818437e-04, -7.06598104e-04, -4.18600161e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.00046558, 0.00040655, 0.00026715, ..., 0.00028133, 0.00025444,
#          0.00012022]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 0.00024328,  0.00025187,  0.00024433, ..., -0.00027711,
#          -0.00023888, -0.00012207]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 0.0004597 ,  0.00052412,  0.00051747, ..., -0.00019851,
#           0.00064357,  0.0007476 ]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-3.52866482e-06,  7.40494579e-06,  3.77758988e-06, ...,
#          -2.93669582e-04, -2.39408051e-04, -1.14762661e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-7.20290700e-06, -4.91351821e-05,  7.69633334e-06, ...,
#           1.04470389e-04,  4.67100093e-04,  3.94294213e-04]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([0.00023436, 0.00028251, 0.00025507, ..., 0.0002727 , 0.00024473,
#          0.00012689]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 0.00023934,  0.00038971,  0.00049308, ..., -0.00023278,
#          -0.00021067, -0.00015368]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.00047813, -0.00067699, -0.00074336, ...,  0.00027711,
#           0.00023888,  0.00012207]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([-0.0004801 , -0.00055341, -0.00049623, ...,  0.00023566,
#           0.00018255,  0.00014947]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 2.45755218e-04,  3.11603420e-04,  2.42515162e-04, ...,
#          -3.09529220e-04, -2.27069817e-04, -9.44167114e-05]),
#   'sampling_rate': 16000},
#  {'path': None,
#   'array': array([ 4.06379331e-06, -4.13678572e-05, -4.46583726e-06, ...,
#           1.44555350e-04,  2.65822528e-05, -4.87003272e-05]),
#   'sampling_rate': 16000}]

# %%
from transformers import WhisperTokenizer, WhisperFeatureExtractor
MODEL_NAME = "openai/whisper-large-v3"
tokenizer = WhisperTokenizer.from_pretrained(MODEL_NAME, language="german", task="transcribe")
feature_extractor = WhisperTokenizer.from_pretrained(MODEL_NAME, language="german", task="transcribe")

# %%
import numpy as np

def time_stretch(audio, rate=1.0):
    return librosa.effects.time_stretch(audio, rate=rate)

def pitch_shift(audio, sr, n_steps):
    return librosa.effects.pitch_shift(audio, sr=sr, n_steps=n_steps)

def add_noise(audio, noise_factor=0.005):
    noise = np.random.randn(len(audio))
    augmented_audio = audio + noise_factor * noise
    return np.clip(augmented_audio, -1, 1)

# %%
import librosa
import numpy as np

def preprocess_audio(audio, sr):
    # Trim silence
    audio, _ = librosa.effects.trim(audio, top_db=20)
    
    # Apply pre-emphasis filter
    audio = librosa.effects.preemphasis(audio)
    
    # Normalize audio
    audio = librosa.util.normalize(audio)
    
    # Add noise for robustness (optional)
    noise_factor = 0.005
    noise = np.random.randn(len(audio))
    augmented_audio = audio + noise_factor * noise
    
    # Ensure the audio is in the correct range
    augmented_audio = np.clip(augmented_audio, -1, 1)
    
    return augmented_audio

def apply_augmentation(audio, sr):
    augmented_audio = audio
    
    # Randomly apply augmentations
    if np.random.rand() < 0.5:
        augmented_audio = time_stretch(augmented_audio, rate=np.random.uniform(0.8, 1.2))
    if np.random.rand() < 0.5:
        augmented_audio = pitch_shift(augmented_audio, sr, n_steps=np.random.uniform(-2, 2))
    if np.random.rand() < 0.5:
        augmented_audio = add_noise(augmented_audio, noise_factor=np.random.uniform(0.001, 0.01))
    
    return augmented_audio

# %%
import numpy as np
import logging

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

def prepare_dataset(batch):
    try:
        # Extract audio data and sampling rate
        audio_data = batch["audio"]["array"]
        sampling_rate = batch["audio"]["sampling_rate"]
        
        # Apply preprocessing and augmentation
        preprocessed_audio = preprocess_audio(audio_data, sampling_rate)
        augmented_audio = apply_augmentation(preprocessed_audio, sampling_rate)
        
        # Compute log-Mel input features from augmented audio array
        batch["input_features"] = feature_extractor(augmented_audio, sampling_rate=sampling_rate).input_features[0]
        
        # Ensure 'text_asr' is a string
        if isinstance(batch["text_asr"], (list, np.ndarray)):
            text = " ".join(map(str, batch["text_asr"]))
        elif not isinstance(batch["text_asr"], str):
            text = str(batch["text_asr"])
        else:
            text = batch["text_asr"]
        
        # Encode target text to label ids
        batch["labels"] = tokenizer(text).input_ids
        return batch
    except Exception as e:
        logger.error(f"Error processing batch: {e}")
        logger.error(f"Problematic batch: {batch}")
        raise

# Apply the updated prepare_dataset function
ds = ds.map(prepare_dataset, remove_columns=ds.column_names["train"], num_proc=4)
# Out:
# Map (num_proc=4):   0%|          | 0/488 [00:00<?, ? examples/s]ERROR:__main__:Error processing batch: text input must be of type `str` (single example), `List[str]` (batch or single pretokenized example) or `List[List[str]]` (batch of pretokenized examples).
# ERROR:__main__:Problematic batch: {'text_asr': 'ja hallo guten Tag ich wollte dir ihre App benutzen und die App schließt sich aber die ganze Zeit wenn ich mich anmelden möchte und da wollte ich mal fragen was war los ist', 'audio': {'path': None, 'array': array([0.00030293, 0.00046724, 0.00018382, ..., 0.00030342, 0.00027104,
#        0.00010502]), 'sampling_rate': 16000}}
# Map (num_proc=4):   0%|          | 0/488 [00:16<?, ? examples/s]ERROR:__main__:Error processing batch: text input must be of type `str` (single example), `List[str]` (batch or single pretokenized example) or `List[List[str]]` (batch of pretokenized examples).
# ERROR:__main__:Problematic batch: {'text_asr': 'ja schönen guten Tag ich habe ein problem mit meiner Karte und so war ich vorhin einkaufen und konnte leider nicht bezahlen da bräuchte ich zu Hilfe und zwar', 'audio': {'path': None, 'array': array([ 3.02155968e-07,  1.34381844e-05, -4.49617801e-07, ...,
#        -6.04857951e-02, -4.89357859e-02, -2.37017609e-02]), 'sampling_rate': 16000}}
# Map (num_proc=4):   0%|          | 0/488 [00:16<?, ? examples/s]ERROR:__main__:Error processing batch: text input must be of type `str` (single example), `List[str]` (batch or single pretokenized example) or `List[List[str]]` (batch of pretokenized examples).
# ERROR:__main__:Problematic batch: {'text_asr': 'Hallo ich möchte gerne eine Rechnung bezahlen und muss eine Zahlung tätigen', 'audio': {'path': None, 'array': array([ 3.64484731e-06,  2.05552060e-05, -4.09452332e-06, ...,
#         1.03963466e-04, -1.85191107e-04, -2.70722026e-04]), 'sampling_rate': 16000}}
# ERROR:__main__:Error processing batch: text input must be of type `str` (single example), `List[str]` (batch or single pretokenized example) or `List[List[str]]` (batch of pretokenized examples).
# ERROR:__main__:Problematic batch: {'text_asr': 'ich benutze ja eine Karte von ihnen leider funktioniert sie gerade nicht und zwar werden meine Bezahlungen immer mit dieser Karte abgelehnt können Sie da was machen', 'audio': {'path': None, 'array': array([-2.20033951e-04, -2.70162272e-05,  2.20555798e-04, ...,
#         2.43170914e-04,  4.19961543e-05, -1.16602736e-04]), 'sampling_rate': 16000}}
# Map (num_proc=4):   0%|          | 0/488 [00:16<?, ? examples/s]
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/pr3_venv/lib/python3.10/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda3/envs/pr3_venv/lib/python3.10/site-packages/datasets/utils/py_utils.py", line 678, in _write_generator_to_queue
#     for i, result in enumerate(func(**kwargs)):
#   File "/opt/anaconda3/envs/pr3_venv/lib/python3.10/site-packages/datasets/arrow_dataset.py", line 3522, in _map_single
#     example = apply_function_on_filtered_inputs(example, i, offset=offset)
#   File "/opt/anaconda3/envs/pr3_venv/lib/python3.10/site-packages/datasets/arrow_dataset.py", line 3421, in apply_function_on_filtered_inputs
#     processed_inputs = function(*fn_args, *additional_args, **fn_kwargs)
#   File "/var/folders/sf/f6mp34nd5vl3m3wt1sk575br0000gn/T/ipykernel_52982/1161990634.py", line 18, in prepare_dataset
#     batch["input_features"] = feature_extractor(augmented_audio, sampling_rate=sampling_rate).input_features[0]
#   File "/opt/anaconda3/envs/pr3_venv/lib/python3.10/site-packages/transformers/tokenization_utils_base.py", line 3073, in __call__
#     encodings = self._call_one(text=text, text_pair=text_pair, **all_kwargs)
#   File "/opt/anaconda3/envs/pr3_venv/lib/python3.10/site-packages/transformers/tokenization_utils_base.py", line 3132, in _call_one
#     raise ValueError(
# ValueError: text input must be of type `str` (single example), `List[str]` (batch or single pretokenized example) or `List[List[str]]` (batch of pretokenized examples).
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 37
#      34         raise
#      36 # Apply the updated prepare_dataset function
# ---> 37 ds = ds.map(prepare_dataset, remove_columns=ds.column_names["train"], num_proc=4)
#
# File /opt/anaconda3/envs/pr3_venv/lib/python3.10/site-packages/datasets/dataset_dict.py:869, in DatasetDict.map(self, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_names, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, desc)
#     866 if cache_file_names is None:
#     867     cache_file_names = {k: None for k in self}
#     868 return DatasetDict(
# --> 869     {
#     870         k: dataset.map(
#     871             function=function,
#     872             with_indices=with_indices,
#     873             with_rank=with_rank,
#     874             input_columns=input_columns,
#     875             batched=batched,
#     876             batch_size=batch_size,
#     877             drop_last_batch=drop_last_batch,
#     878             remove_columns=remove_columns,
#     879             keep_in_memory=keep_in_memory,
#     880             load_from_cache_file=load_from_cache_file,
#     881             cache_file_name=cache_file_names[k],
#     882             writer_batch_size=writer_batch_size,
#     883             features=features,
#     884             disable_nullable=disable_nullable,
#     885             fn_kwargs=fn_kwargs,
#     886             num_proc=num_proc,
#     887             desc=desc,
#     888         )
#     889         for k, dataset in self.items()
#     890     }
#     891 )
#
# File /opt/anaconda3/envs/pr3_venv/lib/python3.10/site-packages/datasets/dataset_dict.py:870, in <dictcomp>(.0)
#     866 if cache_file_names is None:
#     867     cache_file_names = {k: None for k in self}
#     868 return DatasetDict(
#     869     {
# --> 870         k: dataset.map(
#     871             function=function,
#     872             with_indices=with_indices,
#     873             with_rank=with_rank,
#     874             input_columns=input_columns,
#     875             batched=batched,
#     876             batch_size=batch_size,
#     877             drop_last_batch=drop_last_batch,
#     878             remove_columns=remove_columns,
#     879             keep_in_memory=keep_in_memory,
#     880             load_from_cache_file=load_from_cache_file,
#     881             cache_file_name=cache_file_names[k],
#     882             writer_batch_size=writer_batch_size,
#     883             features=features,
#     884             disable_nullable=disable_nullable,
#     885             fn_kwargs=fn_kwargs,
#     886             num_proc=num_proc,
#     887             desc=desc,
#     888         )
#     889         for k, dataset in self.items()
#     890     }
#     891 )
#
# File /opt/anaconda3/envs/pr3_venv/lib/python3.10/site-packages/datasets/arrow_dataset.py:602, in transmit_tasks.<locals>.wrapper(*args, **kwargs)
#     600     self: "Dataset" = kwargs.pop("self")
#     601 # apply actual function
# --> 602 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     603 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     604 for dataset in datasets:
#     605     # Remove task templates if a column mapping of the template is no longer valid
#
# File /opt/anaconda3/envs/pr3_venv/lib/python3.10/site-packages/datasets/arrow_dataset.py:567, in transmit_format.<locals>.wrapper(*args, **kwargs)
#     560 self_format = {
#     561     "type": self._format_type,
#     562     "format_kwargs": self._format_kwargs,
#     563     "columns": self._format_columns,
#     564     "output_all_columns": self._output_all_columns,
#     565 }
#     566 # apply actual function
# --> 567 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     568 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     569 # re-apply format to the output
#
# File /opt/anaconda3/envs/pr3_venv/lib/python3.10/site-packages/datasets/arrow_dataset.py:3253, in Dataset.map(self, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, suffix_template, new_fingerprint, desc)
#    3247 logger.info(f"Spawning {num_proc} processes")
#    3248 with hf_tqdm(
#    3249     unit=" examples",
#    3250     total=pbar_total,
#    3251     desc=(desc or "Map") + f" (num_proc={num_proc})",
#    3252 ) as pbar:
# -> 3253     for rank, done, content in iflatmap_unordered(
#    3254         pool, Dataset._map_single, kwargs_iterable=kwargs_per_job
#    3255     ):
#    3256         if done:
#    3257             shards_done += 1
#
# File /opt/anaconda3/envs/pr3_venv/lib/python3.10/site-packages/datasets/utils/py_utils.py:718, in iflatmap_unordered(pool, func, kwargs_iterable)
#     715 finally:
#     716     if not pool_changed:
#     717         # we get the result in case there's an error to raise
# --> 718         [async_result.get(timeout=0.05) for async_result in async_results]
#
# File /opt/anaconda3/envs/pr3_venv/lib/python3.10/site-packages/datasets/utils/py_utils.py:718, in <listcomp>(.0)
#     715 finally:
#     716     if not pool_changed:
#     717         # we get the result in case there's an error to raise
# --> 718         [async_result.get(timeout=0.05) for async_result in async_results]
#
# File /opt/anaconda3/envs/pr3_venv/lib/python3.10/site-packages/multiprocess/pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# ValueError: text input must be of type `str` (single example), `List[str]` (batch or single pretokenized example) or `List[List[str]]` (batch of pretokenized examples).

# %%
ds = ds.map(prepare_dataset, remove_columns=ds.column_names["train"], num_proc=4)
# Out:
# Map (num_proc=4):   0%|          | 0/488 [00:15<?, ? examples/s]
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/pr3_venv/lib/python3.10/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda3/envs/pr3_venv/lib/python3.10/site-packages/datasets/utils/py_utils.py", line 678, in _write_generator_to_queue
#     for i, result in enumerate(func(**kwargs)):
#   File "/opt/anaconda3/envs/pr3_venv/lib/python3.10/site-packages/datasets/arrow_dataset.py", line 3522, in _map_single
#     example = apply_function_on_filtered_inputs(example, i, offset=offset)
#   File "/opt/anaconda3/envs/pr3_venv/lib/python3.10/site-packages/datasets/arrow_dataset.py", line 3421, in apply_function_on_filtered_inputs
#     processed_inputs = function(*fn_args, *additional_args, **fn_kwargs)
#   File "/var/folders/sf/f6mp34nd5vl3m3wt1sk575br0000gn/T/ipykernel_52982/742969532.py", line 46, in prepare_dataset
#     batch["input_features"] = feature_extractor(augmented_audio, sampling_rate=audio["sampling_rate"]).input_features[0]
#   File "/opt/anaconda3/envs/pr3_venv/lib/python3.10/site-packages/transformers/tokenization_utils_base.py", line 3073, in __call__
#     encodings = self._call_one(text=text, text_pair=text_pair, **all_kwargs)
#   File "/opt/anaconda3/envs/pr3_venv/lib/python3.10/site-packages/transformers/tokenization_utils_base.py", line 3132, in _call_one
#     raise ValueError(
# ValueError: text input must be of type `str` (single example), `List[str]` (batch or single pretokenized example) or `List[List[str]]` (batch of pretokenized examples).
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 ds = ds.map(prepare_dataset, remove_columns=ds.column_names["train"], num_proc=4)
#
# File /opt/anaconda3/envs/pr3_venv/lib/python3.10/site-packages/datasets/dataset_dict.py:869, in DatasetDict.map(self, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_names, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, desc)
#     866 if cache_file_names is None:
#     867     cache_file_names = {k: None for k in self}
#     868 return DatasetDict(
# --> 869     {
#     870         k: dataset.map(
#     871             function=function,
#     872             with_indices=with_indices,
#     873             with_rank=with_rank,
#     874             input_columns=input_columns,
#     875             batched=batched,
#     876             batch_size=batch_size,
#     877             drop_last_batch=drop_last_batch,
#     878             remove_columns=remove_columns,
#     879             keep_in_memory=keep_in_memory,
#     880             load_from_cache_file=load_from_cache_file,
#     881             cache_file_name=cache_file_names[k],
#     882             writer_batch_size=writer_batch_size,
#     883             features=features,
#     884             disable_nullable=disable_nullable,
#     885             fn_kwargs=fn_kwargs,
#     886             num_proc=num_proc,
#     887             desc=desc,
#     888         )
#     889         for k, dataset in self.items()
#     890     }
#     891 )
#
# File /opt/anaconda3/envs/pr3_venv/lib/python3.10/site-packages/datasets/dataset_dict.py:870, in <dictcomp>(.0)
#     866 if cache_file_names is None:
#     867     cache_file_names = {k: None for k in self}
#     868 return DatasetDict(
#     869     {
# --> 870         k: dataset.map(
#     871             function=function,
#     872             with_indices=with_indices,
#     873             with_rank=with_rank,
#     874             input_columns=input_columns,
#     875             batched=batched,
#     876             batch_size=batch_size,
#     877             drop_last_batch=drop_last_batch,
#     878             remove_columns=remove_columns,
#     879             keep_in_memory=keep_in_memory,
#     880             load_from_cache_file=load_from_cache_file,
#     881             cache_file_name=cache_file_names[k],
#     882             writer_batch_size=writer_batch_size,
#     883             features=features,
#     884             disable_nullable=disable_nullable,
#     885             fn_kwargs=fn_kwargs,
#     886             num_proc=num_proc,
#     887             desc=desc,
#     888         )
#     889         for k, dataset in self.items()
#     890     }
#     891 )
#
# File /opt/anaconda3/envs/pr3_venv/lib/python3.10/site-packages/datasets/arrow_dataset.py:602, in transmit_tasks.<locals>.wrapper(*args, **kwargs)
#     600     self: "Dataset" = kwargs.pop("self")
#     601 # apply actual function
# --> 602 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     603 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     604 for dataset in datasets:
#     605     # Remove task templates if a column mapping of the template is no longer valid
#
# File /opt/anaconda3/envs/pr3_venv/lib/python3.10/site-packages/datasets/arrow_dataset.py:567, in transmit_format.<locals>.wrapper(*args, **kwargs)
#     560 self_format = {
#     561     "type": self._format_type,
#     562     "format_kwargs": self._format_kwargs,
#     563     "columns": self._format_columns,
#     564     "output_all_columns": self._output_all_columns,
#     565 }
#     566 # apply actual function
# --> 567 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     568 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     569 # re-apply format to the output
#
# File /opt/anaconda3/envs/pr3_venv/lib/python3.10/site-packages/datasets/arrow_dataset.py:3253, in Dataset.map(self, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, suffix_template, new_fingerprint, desc)
#    3247 logger.info(f"Spawning {num_proc} processes")
#    3248 with hf_tqdm(
#    3249     unit=" examples",
#    3250     total=pbar_total,
#    3251     desc=(desc or "Map") + f" (num_proc={num_proc})",
#    3252 ) as pbar:
# -> 3253     for rank, done, content in iflatmap_unordered(
#    3254         pool, Dataset._map_single, kwargs_iterable=kwargs_per_job
#    3255     ):
#    3256         if done:
#    3257             shards_done += 1
#
# File /opt/anaconda3/envs/pr3_venv/lib/python3.10/site-packages/datasets/utils/py_utils.py:718, in iflatmap_unordered(pool, func, kwargs_iterable)
#     715 finally:
#     716     if not pool_changed:
#     717         # we get the result in case there's an error to raise
# --> 718         [async_result.get(timeout=0.05) for async_result in async_results]
#
# File /opt/anaconda3/envs/pr3_venv/lib/python3.10/site-packages/datasets/utils/py_utils.py:718, in <listcomp>(.0)
#     715 finally:
#     716     if not pool_changed:
#     717         # we get the result in case there's an error to raise
# --> 718         [async_result.get(timeout=0.05) for async_result in async_results]
#
# File /opt/anaconda3/envs/pr3_venv/lib/python3.10/site-packages/multiprocess/pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# ValueError: text input must be of type `str` (single example), `List[str]` (batch or single pretokenized example) or `List[List[str]]` (batch of pretokenized examples).

# %%
# mps config
import torch

device = "mps" if torch.backends.mps.is_available() else "cpu"
torch_dtype = torch.float16 if torch.backends.mps.is_available() else torch.float32

# %%
from transformers import WhisperFeatureExtractor, WhisperProcessor
MODEL_NAME = "openai/whisper-large-v3"
feature_extractor = WhisperFeatureExtractor.from_pretrained(MODEL_NAME)
processor = WhisperProcessor.from_pretrained(MODEL_NAME, language="german", task="transcribe")

# %%
print(ds["train"][0])

# %%
def prepare_dataset(batch):
    # load and resample audio data from 48 to 16kHz
    audio = batch["audio"]

    # compute log-Mel input features from input audio array
    batch["input_features"] = feature_extractor(audio["array"], sampling_rate=audio["sampling_rate"]).input_features[0]

    # encode target text to label ids
    batch["labels"] = tokenizer(batch["text_asr"]).input_ids
    return batch

# %%
ds = ds.map(prepare_dataset, remove_columns=ds.column_names["train"], num_proc=4)

# %%
from transformers import WhisperForConditionalGeneration

model = WhisperForConditionalGeneration.from_pretrained(MODEL_NAME).to(device)
# model = torch.nn.DataParallel(model)
# model = torch.compile(model)

# %%
model.generation_config.language = "german"
model.generation_config.task = "transcribe"
model.generation_config.forced_decoder_ids = None
# torch._dynamo.config.suppress_errors = True


# ds = ds.with_format("torch", device="mps")

# %%
import torch

from dataclasses import dataclass
from typing import Any, Dict, List, Union

@dataclass
class DataCollatorSpeechSeq2SeqWithPadding:
    processor: Any
    decoder_start_token_id: int

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lengths and need different padding methods
        # first treat the audio inputs by simply returning torch tensors
        input_features = [{"input_features": feature["input_features"]} for feature in features]
        batch = self.processor.feature_extractor.pad(input_features, return_tensors="pt")

        # get the tokenized label sequences
        label_features = [{"input_ids": feature["labels"]} for feature in features]
        # pad the labels to max length
        labels_batch = self.processor.tokenizer.pad(label_features, return_tensors="pt")

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        # if bos token is appended in previous tokenization step,
        # cut bos token here as it's append later anyways
        if (labels[:, 0] == self.decoder_start_token_id).all().cpu().item():
            labels = labels[:, 1:]

        batch["labels"] = labels

        return batch

# %%
data_collator = DataCollatorSpeechSeq2SeqWithPadding(
    processor=processor,
    decoder_start_token_id=model.config.decoder_start_token_id,
)

# %%
import evaluate

metric = evaluate.load("wer")

# %%
def compute_metrics(pred):
    pred_ids = pred.predictions
    label_ids = pred.label_ids

    # replace -100 with the pad_token_id
    label_ids[label_ids == -100] = tokenizer.pad_token_id

    # we do not want to group tokens when computing the metrics
    pred_str = tokenizer.batch_decode(pred_ids, skip_special_tokens=True)
    label_str = tokenizer.batch_decode(label_ids, skip_special_tokens=True)

    wer = 100 * metric.compute(predictions=pred_str, references=label_str)

    return {"wer": wer}

# %%
from transformers import Seq2SeqTrainingArguments

training_args = Seq2SeqTrainingArguments(
    output_dir="./whisper-large-ger-lr1.5",  
    gradient_accumulation_steps=2,  # increase by 2x for every 2x decrease in batch size
    learning_rate=1e-5,
    warmup_steps=4,
    max_steps=61,
    gradient_checkpointing=True,
    evaluation_strategy="steps",
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    predict_with_generate=True,
    save_steps=8,
    eval_steps=8,
    logging_steps=8,
    load_best_model_at_end=True,
    metric_for_best_model="wer",
    greater_is_better=False,
)

# %%
from transformers import Seq2SeqTrainer

trainer = Seq2SeqTrainer(
    args=training_args,
    model=model,
    train_dataset=ds["train"],
    eval_dataset=ds["test"],
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    tokenizer=processor.feature_extractor,
)

# %%
processor.save_pretrained(training_args.output_dir)

# %%
trainer.train()

# %%
import pandas as pd
trainer_history = pd.DataFrame(trainer.state.log_history)
trainer_history.groupby('step').first().reset_index()
trainer_history

# %%
import matplotlib.pyplot as plt

# Plot WER over training steps
plt.figure(figsize=(12, 8))

# Plot WER
plt.subplot(2, 1, 1)
plt.plot(trainer_history['step'], trainer_history['eval_wer'], marker='o', label='WER')
plt.title("WER over Training Steps")
plt.xlabel("Steps")
plt.ylabel("WER Evaluation")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import time
from transformers import WhisperForConditionalGeneration, WhisperProcessor

# Define the path to the model checkpoint
model_path = "/Users/shabiras/Developer/Learn/AI/NLP/INDONESIA AI/Project_3/whisper-small-ger-lr3.5/checkpoint-61"

# Load the best fine-tuned model
try:
    model = WhisperForConditionalGeneration.from_pretrained(model_path)
    processor = WhisperProcessor.from_pretrained(model_path)
    print("Model and processor loaded successfully.")
except OSError as e:
    print(f"Error loading model or processor: {e}")

# Inference function
def transcribe(audio):
    input_features = processor(audio["array"], sampling_rate=audio["sampling_rate"], return_tensors="pt").input_features
    predicted_ids = model.generate(input_features)
    transcription = processor.batch_decode(predicted_ids, skip_special_tokens=True)
    return transcription[0]

# %%
# Run inference on three samples
for i in range(3):
    sample = ds2["test"][i]
    
    start_time = time.time()
    transcription = transcribe(sample["audio"])
    end_time = time.time()
    
    inference_time = end_time - start_time
    
    print(f"Sample {i+1}:")
    print(f"Reference: {sample['text_asr']}")
    print(f"Prediction: {transcription}")
    print(f"Inference time: {inference_time:.4f} seconds")
    print()

# Calculate overall WER for these three samples
wer = metric.compute(predictions=[transcribe(ds["test"][i]["audio"]) for i in range(3)],
                     references=[ds2["test"][i]["text_asr"] for i in range(3)])
print(f"WER for 3 samples: {wer}")

# %%
# !pip install sounddevice

# %%
import sounddevice as sd
import numpy as np

# Function to record audio from the microphone
def record_audio(duration, sample_rate=16000):
    print("Recording...")
    audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1, dtype='float32')
    sd.wait()  # Wait until the recording is finished
    print("Recording finished.")
    audio = np.squeeze(audio)  # Remove single-dimensional entries
    return {"array": audio, "sampling_rate": sample_rate}

# Record audio from the microphone
duration = 5  # Record for 5 seconds
audio = record_audio(duration)

# Transcribe the recorded audio
transcription = transcribe(audio)
print("Transcription:", transcription)
